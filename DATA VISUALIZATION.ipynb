# %%
import matplotlib.pyplot as plt
from PIL import Image
from scipy import ndimage
import matplotlib.image as mpimg
import cv2
import os
import glob
import pandas as pd
import numpy as np

# %%
img_dir = "images" # Enter Directory of all images 
data_path = os.path.join(img_dir,'*g')
files = glob.glob(data_path)


img = cv2.imread(files[i])
plt.imshow(img)

# %%
labels_train = pd.read_csv('train.csv')
labels_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1646 entries, 0 to 1645
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   image_names       1646 non-null   object
#  1   emergency_or_not  1646 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 25.8+ KB

# %%
def show_image(num):
    img = cv2.imread(files[num])
    plt.imshow(img)
    print ('image shape is',img.shape)
    print('image class is',labels_train.iloc[[num]])

# %%
show_image(20)
# Out:
# image shape is (224, 224, 3)
# image class is    image_names  emergency_or_not
# 20     907.jpg                 1
